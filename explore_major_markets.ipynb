# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime, timedelta 
from scipy.stats import pearsonr


import wrangle as wr

import warnings
warnings.filterwarnings('ignore')

# %%
annual_sa = wr.sales('annual_home_sales_sa_metro.csv')
monthly_sa = wr.sales('monthly_home_sales_sa.csv')
pct_sa = wr.percent_distribution('pct_distribution_sa_metro.csv')

# %%
annual_sa.head(3)
# Out:
#    date  sales  dollar_volume  average_price  median_price  total_listings  \
# 0  1990   6322      495787279          78423         62479            8877
# 1  1991   6431      517302399          80439         63815            6875
# 2  1992   6895      587653358          85229         70146            6009
#
#    months_inventory
# 0              15.2
# 1              10.8
# 2               9.7

# %%
monthly_sa.sample(3)
# Out:
#           date  sales  dollar_volume  average_price  median_price  \
# 282 2013-07-01   2512      540309047         215091        177000
# 295 2014-08-01   2576      560427192         217557        180000
# 224 2008-09-01   1685      297720965         176689        144398
#
#      total_listings  months_inventory
# 282            9830               5.1
# 295            9337               4.5
# 224           13682               7.8

# %%
pct_sa.tail(3)
# Out:
# 0                    2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# price_range
# $500,000 - $749,999   2.3   2.3   2.7   3.0   3.3   3.4   3.6   3.9   4.4
# $750,000 - $999,999   0.5   0.6   0.8   0.7   0.8   0.7   0.8   0.8   1.0
# 1,000,000             0.4   0.4   0.4   0.4   0.5   0.5   0.5   0.6   0.6
#
# 0                    2020  2021  2022
# price_range
# $500,000 - $749,999   5.8   8.8  11.9
# $750,000 - $999,999   1.3   2.2   3.1
# 1,000,000             0.9   1.5   2.0

# %%
annual_aus = wr.sales('annual_aus.csv')
annual_dal = wr.sales('annual_dal.csv')
annual_hou = wr.sales('annual_hou.csv')

# %%
annual_aus.head()
# Out:
#    date  sales  dollar_volume  average_price  median_price  total_listings  \
# 0  1990   7068      579669083          82013         72252            4412
# 1  1991   7485      661674435          88400         75865            3552
# 2  1992   8389      832936284          99289         82929            3020
# 3  1993   9784     1076687995         110046         90949            2860
# 4  1994  10418     1207051547         115862         95158            3645
#
#    months_inventory
# 0               6.5
# 1               4.6
# 2               3.6
# 3               3.2
# 4               3.9

# %%
mon_aus = wr.sales('monthly_aus.csv')
mon_dal = wr.sales('monthly_dal.csv')
mon_hou = wr.sales('monthly_hou.csv')

# %%
mon_hou.head(3)
# Out:
#         date  sales  dollar_volume  average_price  median_price  \
# 0 1990-01-01   2500      214427500          85771         45500
# 1 1990-02-01   1935      171518400          88640         66231
# 2 1990-03-01   2554      219963250          86125         67052
#
#    total_listings  months_inventory
# 0           22318               8.9
# 1           23191              10.5
# 2           24247              10.4

# %%
pct_aus = wr.percent_distribution('pct_dist_aus.csv')

pct_dal = wr.percent_distribution('price_dist_dal.csv')

pct_hou = wr.percent_distribution('pct_dist_hou.csv')

# %%
pct_dal
# Out:
# 0                    2011  2012  2013  2014  2015  2016  2017  2018  2019  \
# price_range
# $0 - $69,999         14.5  11.3   7.2   4.9   3.6   2.4   1.4   0.8   0.6
# $70,000 - $99,999    12.1  10.8   8.6   7.0   5.2   3.5   2.3   1.6   1.3
# $100,000 - $149,999  22.7  22.3  21.5  20.3  16.8  12.9   8.6   6.4   4.7
# $150,000 - $199,999  17.1  18.7  20.1  20.4  20.2  19.9  17.7  15.7  14.0
# $200,000 - $249,999  10.3  11.2  12.5  13.9  15.2  16.5  17.9  19.4  20.3
# $250,000 - $299,999   7.3   8.1   9.1   9.9  11.3  12.8  14.5  15.9  16.9
# $300,000 - $399,999   7.6   8.5  10.1  11.2  13.4  15.6  18.5  19.7  21.2
# $400,000 - $499,999   3.3   3.7   4.8   5.5   6.3   7.6   8.7   9.5   9.8
# $500,000 - $749,999   3.0   3.2   3.8   4.3   5.2   6.0   6.9   7.2   7.6
# $750,000 - $999,999   1.0   1.0   1.2   1.3   1.5   1.5   1.8   1.8   1.9
# 1,000,000             1.1   1.1   1.1   1.3   1.3   1.4   1.7   1.8   1.8
#
# 0                    2020  2021  2022
# price_range
# $0 - $69,999          0.4   0.2   0.1
# $70,000 - $99,999     0.8   0.5   0.3
# $100,000 - $149,999   3.4   2.2   1.4
# $150,000 - $199,999  10.3   5.6   3.2
# $200,000 - $249,999  19.2  11.3   6.5
# $250,000 - $299,999  17.8  16.2  10.6
# $300,000 - $399,999  23.4  26.6  27.2
# $400,000 - $499,999  11.3  15.6  19.2
# $500,000 - $749,999   8.9  14.5  20.6
# $750,000 - $999,999   2.3   3.8   6.2
# 1,000,000             2.1   3.5   4.0

# %%
sns.lmplot(data = monthly_sa, x = 'sales', y = 'average_price', line_kws= {'color': 'red'})

# %%
plt.subplot(2, 2, 1)
sns.regplot(data=mon_dal, x='sales', y='average_price', line_kws={'color': 'red'})
plt.title('Monthly Dallas')

plt.subplot(2, 2, 2)
sns.regplot(data=mon_aus, x='sales', y='average_price', line_kws={'color': 'red'})
plt.title('Monthly Austin')

plt.subplot(2, 2, 3)
sns.regplot(data=mon_hou, x='sales', y='average_price', line_kws={'color': 'red'})
plt.title('Monthly Houston')

plt.subplot(2, 2, 4)
sns.regplot(data=monthly_sa, x='sales', y='average_price', line_kws={'color': 'red'})
plt.title('Monthly San Antonio')

plt.tight_layout()
plt.show()

# %%
monthly_sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              399 non-null    datetime64[ns]
#  1   sales             399 non-null    int64
#  2   dollar_volume     399 non-null    int64
#  3   average_price     399 non-null    int64
#  4   median_price      399 non-null    int64
#  5   total_listings    399 non-null    int64
#  6   months_inventory  399 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(5)
# memory usage: 21.9 KB

# %%
sns.lineplot(data = monthly_sa, x = 'date', y = 'average_price')
plt.xlim(pd.Timestamp('2008-01-01'), pd.Timestamp('2023-12-31'))
# Out:
# (13879.0, 19722.0)

# %%
monthly_sa.describe()
# Out:
#              sales  dollar_volume  average_price   median_price  \
# count   399.000000   3.990000e+02     399.000000     399.000000
# mean   1728.310777   3.609929e+08  173686.646617  144126.691729
# std     904.809405   3.248761e+08   75881.635427   66366.479999
# min     353.000000   2.435206e+07   68986.000000   56587.000000
# 25%    1025.500000   1.166339e+08  109275.000000   86948.500000
# 50%    1639.000000   2.680779e+08  168642.000000  139139.000000
# 75%    2379.500000   5.006814e+08  220298.500000  183150.000000
# max    4339.000000   1.479237e+09  395941.000000  336200.000000
#
#        total_listings  months_inventory
# count      399.000000        399.000000
# mean      8437.759398          6.368421
# std       2255.459942          3.434389
# min       3806.000000          1.100000
# 25%       6711.500000          3.850000
# 50%       8315.000000          5.500000
# 75%       9498.000000          8.200000
# max      14154.000000         22.100000

# %%
markets = {'dallas': mon_dal, 'houston':mon_hou, 'san antonio':monthly_sa, 'austin':mon_aus}

for df_name, df in markets.items():
    print(f"Max date for {df_name}: {df['date'].max()}")
    print(f"Min date for {df_name}: {df['date'].min()}")
# Out:
# Max date for dallas: 2023-03-01 00:00:00
# Min date for dallas: 1990-01-01 00:00:00
# Max date for houston: 2023-03-01 00:00:00
# Min date for houston: 1990-01-01 00:00:00
# Max date for san antonio: 2023-03-01 00:00:00
# Min date for san antonio: 1990-01-01 00:00:00
# Max date for austin: 2023-03-01 00:00:00
# Min date for austin: 1990-01-01 00:00:00

# %%
monthly_sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              399 non-null    datetime64[ns]
#  1   sales             399 non-null    int64
#  2   dollar_volume     399 non-null    int64
#  3   average_price     399 non-null    int64
#  4   median_price      399 non-null    int64
#  5   total_listings    399 non-null    int64
#  6   months_inventory  399 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(5)
# memory usage: 21.9 KB

# %%
if monthly_sa.isna().sum().le(1).any():
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
if monthly_sa.isna().sum().any() >= 1:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
cities = [mon_aus,mon_dal, mon_hou, monthly_sa]

for df in cities:
    if df.isna().sum().any() >= 1:
        print('yes')
    else: 
        print('no')
# Out:
# no
# no
# no
# no

# %%
def time_df(df):
    df.set_index('date', inplace = True)
    return df

# %%
monthly_sa
# Out:
#           date  sales  dollar_volume  average_price  median_price  \
# 0   1990-01-01    478       35062256          73352         63830
# 1   1990-02-01    363       27456231          75637         60258
# 2   1990-03-01    553       45066182          81494         61548
# 3   1990-04-01    429       38545221          89849         59067
# 4   1990-05-01    537       48376719          90087         62143
# ..         ...    ...            ...            ...           ...
# 394 2022-11-01   2317      851014583         367292        314000
# 395 2022-12-01   2503      934416251         373319        317000
# 396 2023-01-01   1816      663710971         365480        304500
# 397 2023-02-01   2396      857492587         357885        305000
# 398 2023-03-01   3148     1139024429         361825        310000
#
#      total_listings  months_inventory
# 0              8211              17.2
# 1              9280              22.1
# 2              9335              20.1
# 3              9545              20.9
# 4              9588              20.3
# ..              ...               ...
# 394           10061               3.2
# 395            9499               3.1
# 396            9497               3.1
# 397            9514               3.2
# 398            9189               3.1
#
# [399 rows x 7 columns]

# %%
plt.hist(monthly_sa)
plt.xlabel('date')
plt.ylabel('price')
plt.title('distribution of target')
plt.show()

# %%
mon_aus['average_price']
# Out:
# 0       84117
# 1       83460
# 2       80563
# 3       60838
# 4       81798
#         ...
# 394    575923
# 395    552036
# 396    556808
# 397    537124
# 398    563499
# Name: average_price, Length: 399, dtype: int64

# %%
aus = time_df(mon_aus)
aus
# Out:
#             sales  dollar_volume  average_price  median_price  total_listings  \
# date
# 1990-01-01    558       46937286          84117         71000            4391
# 1990-02-01    444       37056240          83460         71199            4343
# 1990-03-01    431       34722653          80563         72497            4459
# 1990-04-01    569       34616822          60838         71998            4545
# 1990-05-01    549       44907102          81798         73694            4731
# ...           ...            ...            ...           ...             ...
# 2022-11-01   2055     1183522245         575923        464000            8738
# 2022-12-01   2508     1384506103         552036        450000            7416
# 2023-01-01   1630      907597030         556808        449990            7243
# 2023-02-01   2132     1145147523         537124        435000            7120
# 2023-03-01   2770     1560892188         563499        450000            8030
#
#             months_inventory
# date
# 1990-01-01               7.9
# 1990-02-01               8.7
# 1990-03-01               9.3
# 1990-04-01               9.1
# 1990-05-01               9.3
# ...                      ...
# 2022-11-01               3.0
# 2022-12-01               2.6
# 2023-01-01               2.6
# 2023-02-01               2.6
# 2023-03-01               3.0
#
# [399 rows x 6 columns]

# %%
dal = time_df(mon_dal)

# %%
hou = time_df(mon_hou)

# %%
monthly_sa = time_df(monthly_sa)

# %%
df =pd.concat([aus['average_price'],dal['average_price'], hou['average_price'], monthly_sa['average_price']], axis=1, keys=['austin','dallas','houston', 'san_antonio'])

# %%
df.shape
# Out:
# (399, 4)

# %%
df
# Out:
#             austin  dallas  houston  san_antonio
# date
# 1990-01-01   84117  105280    85771        73352
# 1990-02-01   83460  106998    88640        75637
# 1990-03-01   80563  104479    86125        81494
# 1990-04-01   60838  106941    90907        89849
# 1990-05-01   81798  111997    86045        90087
# ...            ...     ...      ...          ...
# 2022-11-01  575923  474614   399020       367292
# 2022-12-01  552036  454773   404350       373319
# 2023-01-01  556808  457712   378553       365480
# 2023-02-01  537124  463248   382926       357885
# 2023-03-01  563499  467129   409158       361825
#
# [399 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))
custom_palette = ["red",'black', "seagreen", "dodgerblue"]
sns.lineplot(data=df, linestyle='-', palette=custom_palette, dashes=False)

plt.title("Texas's 4 Major Market Home Prices", fontsize = 20)
plt.xlabel('Date', fontsize = 12)
plt.ylabel('Average Home Price', fontsize = 12)
plt.xticks(fontsize= 10)
plt.yticks(fontsize = 10)
plt.legend(df.columns)
plt.show()

# %%
(600-500)/600
# Out:
# 0.16666666666666666

# %%
sns.scatterplot(data= mon_aus, x='date', y='sales')
plt.show()

# %%
mon_aus.corr()
# Out:
#                      sales  dollar_volume  average_price  median_price  \
# sales             1.000000       0.901115       0.816230      0.802323
# dollar_volume     0.901115       1.000000       0.948623      0.948388
# average_price     0.816230       0.948623       1.000000      0.997861
# median_price      0.802323       0.948388       0.997861      1.000000
# total_listings    0.239915       0.031954       0.103869      0.078134
# months_inventory -0.577996      -0.633095      -0.636412     -0.633934
#
#                   total_listings  months_inventory
# sales                   0.239915         -0.577996
# dollar_volume           0.031954         -0.633095
# average_price           0.103869         -0.636412
# median_price            0.078134         -0.633934
# total_listings          1.000000          0.444968
# months_inventory        0.444968          1.000000

# %%
mon_hou.corr()
# Out:
#                      sales  dollar_volume  average_price  median_price  \
# sales             1.000000       0.942234       0.868802      0.856796
# dollar_volume     0.942234       1.000000       0.949670      0.950183
# average_price     0.868802       0.949670       1.000000      0.995702
# median_price      0.856796       0.950183       0.995702      1.000000
# total_listings    0.008059      -0.134254      -0.094330     -0.113968
# months_inventory -0.720191      -0.734832      -0.789263     -0.779094
#
#                   total_listings  months_inventory
# sales                   0.008059         -0.720191
# dollar_volume          -0.134254         -0.734832
# average_price          -0.094330         -0.789263
# median_price           -0.113968         -0.779094
# total_listings          1.000000          0.426460
# months_inventory        0.426460          1.000000

# %%
mon_dal.corr()
# Out:
#                      sales  dollar_volume  average_price  median_price  \
# sales             1.000000       0.880264       0.755879      0.738715
# dollar_volume     0.880264       1.000000       0.951212      0.947842
# average_price     0.755879       0.951212       1.000000      0.997180
# median_price      0.738715       0.947842       0.997180      1.000000
# total_listings   -0.106354      -0.372179      -0.434759     -0.462928
# months_inventory -0.711001      -0.702385      -0.730074     -0.720347
#
#                   total_listings  months_inventory
# sales                  -0.106354         -0.711001
# dollar_volume          -0.372179         -0.702385
# average_price          -0.434759         -0.730074
# median_price           -0.462928         -0.720347
# total_listings          1.000000          0.502694
# months_inventory        0.502694          1.000000

# %%
monthly_sa.corr()
# Out:
#                      sales  dollar_volume  average_price  median_price  \
# sales             1.000000       0.943490       0.887891      0.890538
# dollar_volume     0.943490       1.000000       0.952482      0.955082
# average_price     0.887891       0.952482       1.000000      0.998364
# median_price      0.890538       0.955082       0.998364      1.000000
# total_listings    0.204863       0.077685       0.206960      0.200130
# months_inventory -0.760588      -0.687776      -0.724649     -0.722375
#
#                   total_listings  months_inventory
# sales                   0.204863         -0.760588
# dollar_volume           0.077685         -0.687776
# average_price           0.206960         -0.724649
# median_price            0.200130         -0.722375
# total_listings          1.000000          0.015908
# months_inventory        0.015908          1.000000

# %%
monthly_sa
# Out:
#             sales  dollar_volume  average_price  median_price  total_listings  \
# date
# 1990-01-01    478       35062256          73352         63830            8211
# 1990-02-01    363       27456231          75637         60258            9280
# 1990-03-01    553       45066182          81494         61548            9335
# 1990-04-01    429       38545221          89849         59067            9545
# 1990-05-01    537       48376719          90087         62143            9588
# ...           ...            ...            ...           ...             ...
# 2022-11-01   2317      851014583         367292        314000           10061
# 2022-12-01   2503      934416251         373319        317000            9499
# 2023-01-01   1816      663710971         365480        304500            9497
# 2023-02-01   2396      857492587         357885        305000            9514
# 2023-03-01   3148     1139024429         361825        310000            9189
#
#             months_inventory
# date
# 1990-01-01              17.2
# 1990-02-01              22.1
# 1990-03-01              20.1
# 1990-04-01              20.9
# 1990-05-01              20.3
# ...                      ...
# 2022-11-01               3.2
# 2022-12-01               3.1
# 2023-01-01               3.1
# 2023-02-01               3.2
# 2023-03-01               3.1
#
# [399 rows x 6 columns]

# %% [markdown]
# ### 1. Does the average price of a metro area have a correlation with its features?
#
# <br>
# $H_0$: There is no correlation between total listings and the average price
#
# $H_a$: There is a correlation between total listings and the average price

# %%
α = 0.05

listing = monthly_sa['total_listings']
home_value = monthly_sa['average_price']

corr, p_value = pearsonr(listing, home_value)

if p_value < α:
    print("Reject the Null Hypothesis. There is a correlation between total listings and average price.")
else:
    print("Fail to reject the Null Hypothesis. There is no correlation between total listings and average price.")
# Out:
# Reject the Null Hypothesis. There is a correlation between total listings and average price.

# %%
corr,p_value
# Out:
# (0.20696011261616198, 3.096541626201449e-05)

# %%
α = 0.05

columns = ['sales','dollar_volume', 'total_listings','months_inventory']
correlation_results = []

for col in columns:
    listing = monthly_sa[col]
    home_value = monthly_sa['average_price']

    corr, p_value = pearsonr(listing, home_value)
    
    correlation_results.append({'feature': col, 'correlation': corr, 'p-value': p_value})

dff = pd.DataFrame(correlation_results)
dff['significance']=dff['p-value'] < α
dff.sort_values('correlation', ascending = False, ignore_index = True)
# Out:
#             feature  correlation        p-value  significance
# 0     dollar_volume     0.952482  4.587489e-207          True
# 1             sales     0.887891  6.151226e-136          True
# 2    total_listings     0.206960   3.096542e-05          True
# 3  months_inventory    -0.724649   3.497582e-66          True

# %%
sns.lineplot(data=monthly_sa, x = 'date', y= 'dollar_volume', color = 'seagreen' )
plt.show()

# %% [markdown]
# ### 2. Do metro areas have a relationship with other metro areas?

# %%
α = 0.05

metros = ['austin','houston','dallas']
correlation_results = []

for metro in metros:
    listing = df[metro]
    home_value = monthly_sa['average_price']

    corr, p_value = pearsonr(listing, home_value)
    
    correlation_results.append({'feature': metro, 'correlation': corr, 'p-value': p_value})

dff = pd.DataFrame(correlation_results)
dff['significance']=dff['p-value'] < α
dff.sort_values('correlation', ascending = False, ignore_index = True, inplace=True)

# %%
dff
# Out:
#    feature  correlation        p-value  significance
# 0  houston     0.990844   0.000000e+00          True
# 1   austin     0.988600   0.000000e+00          True
# 2   dallas     0.986513  3.686149e-314          True

# %%
dff['feature'][0]
# Out:
# 'houston'

# %%
def comparing_markets(mkt1,mkt2,mkt3,mkt4, keys = ['name1', 'name2', 'name3', 'name4']):
    markets = [mkt1,mkt2,mkt3,mkt4]
    
    concat_markets = []
    for market in markets:
        df = time_df(market)
        concat_markets.append(df['average_price'])  

    df = pd.concat(concat_markets, axis=1, 
    keys = keys)
    
    return df

# %%
test = comparing_markets(mon_aus,mon_dal,mon_hou,monthly_sa,
                         keys = ['austin', 'dallas', 'houston', 'san antonio'])

# %%
test
# Out:
#             austin  dallas  houston  san antonio
# date
# 1990-01-01   84117  105280    85771        73352
# 1990-02-01   83460  106998    88640        75637
# 1990-03-01   80563  104479    86125        81494
# 1990-04-01   60838  106941    90907        89849
# 1990-05-01   81798  111997    86045        90087
# ...            ...     ...      ...          ...
# 2022-11-01  575923  474614   399020       367292
# 2022-12-01  552036  454773   404350       373319
# 2023-01-01  556808  457712   378553       365480
# 2023-02-01  537124  463248   382926       357885
# 2023-03-01  563499  467129   409158       361825
#
# [399 rows x 4 columns]

# %%
def create_market_subplots(markets, titles):
    num_markets = len(markets)
    num_rows = (num_markets - 1) // 2 + 1
    num_cols = min(num_markets, 2)
    
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(10, 8))

    for i, market in enumerate(markets):
        row = i // num_cols
        col = i % num_cols
        ax = axs[row, col]
        sns.regplot(data=market, x='sales', y='average_price', line_kws={'color': 'red'}, ax=ax)
        ax.set_title(titles[i])

    plt.tight_layout()
    plt.show()

# %%
markets = [mon_dal, mon_aus, mon_hou, monthly_sa]
titles = ['Monthly Dallas', 'Monthly Austin', 'Monthly Houston', 'Monthly San Antonio']

create_market_subplots(markets, titles)

# %%
def plot_market_home_prices(df, title, x_label, y_label, figsize=(12, 8), palette=None, linestyle='-', dashes=False):
    sns.set_style('whitegrid')
    sns.set_palette(palette)

    plt.figure(figsize=figsize)
    sns.lineplot(data=df, linestyle=linestyle, dashes=dashes)

    plt.title(title, fontsize=20)
    plt.xlabel('')
    plt.ylabel(f'{y_label} ($)', fontsize=17)  # Include currency symbol in y-axis label
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)

    plt.legend(df.columns, fontsize=15)

    sns.despine()
    plt.tight_layout()
    
    plt.show()

# %%
df = test# Your DataFrame containing the data for plotting
title = "Texas's 4 Major Market Home Prices"
x_label = ''
y_label = f'Average Home Price'
custom_palette = ["red", 'black', "seagreen", "dodgerblue"]

plot_market_home_prices(df, title, x_label, y_label, palette=custom_palette)
